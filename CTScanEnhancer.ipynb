# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyushaa7/OptimaScan/blob/main/CTScanEnhancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow keras matplotlib gradio opencv-python
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.43.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.12.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.34.4)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.12.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.16.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.19.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (1.1.8)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import os
import zipfile
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
import gradio as gr

# %%
# Unzip trainA.zip
with zipfile.ZipFile("/content/trainA.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/trainA")

# Unzip testA.zip
with zipfile.ZipFile("/content/testA.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/testA")

# %%
# !ls /content
# Out:
# sample_data  testA.zip	trainA.zip

# %%
import zipfile

print(zipfile.is_zipfile("/content/trainA.zip"))  # Should be True
print(zipfile.is_zipfile("/content/testA.zip"))   # Should be True
# Out:
# True
# True

# %%
def load_images_from_folder(folder, img_size=(128,128)):
    images = []
    for root, dirs, files in os.walk(folder):
        for filename in files:
            if filename.endswith(".png"):
                img = cv2.imread(os.path.join(root, filename), cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img = cv2.resize(img, img_size)
                    images.append(img)
    images = np.array(images, dtype='float32') / 255.0
    images = np.expand_dims(images, axis=-1)
    return images

X_train = load_images_from_folder("/content/trainA")
X_test = load_images_from_folder("/content/testA")

print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (1742, 128, 128, 1)
# Test set shape: (744, 128, 128, 1)

# %%
def add_noise(images, noise_factor=0.3):
    noisy = images + noise_factor * np.random.randn(*images.shape)
    noisy = np.clip(noisy, 0., 1.)
    return noisy

X_train_noisy = add_noise(X_train)
X_test_noisy = add_noise(X_test)

# %%
def build_autoencoder(input_shape=(128,128,1)):
    input_img = layers.Input(shape=input_shape)

    # Encoder
    x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(input_img)
    x = layers.MaxPooling2D((2,2), padding='same')(x)
    x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2), padding='same')(x)

    # Decoder
    x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2,2))(x)
    x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2,2))(x)
    decoded = layers.Conv2D(1, (3,3), activation='sigmoid', padding='same')(x)

    autoencoder = models.Model(input_img, decoded)
    autoencoder.compile(optimizer='adam', loss='mse')
    return autoencoder

autoencoder = build_autoencoder()
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 1)    │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 74,497 (291.00 KB)
#  Trainable params: 74,497 (291.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.fit(
    X_train_noisy, X_train,
    epochs=40,
    batch_size=16,
    shuffle=True,
    validation_data=(X_test_noisy, X_test)
)
# Out:
# Epoch 1/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - loss: 0.0571 - val_loss: 0.0131
# Epoch 2/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - loss: 0.0119 - val_loss: 0.0099
# Epoch 3/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0093 - val_loss: 0.0085
# Epoch 4/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 5/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 6/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 7/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 8/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 9/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 10/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 11/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 12/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 13/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 14/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 15/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 16/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 17/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 18/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 19/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 20/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 21/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 22/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 23/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 24/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 25/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 26/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 27/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 28/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 29/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 30/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 31/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 32/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 33/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 34/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 35/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 36/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 37/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 38/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 39/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 40/40
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - loss: 0.0043 - val_loss: 0.0045

# %%
autoencoder.save("autoencoder.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4056281004.py in <cell line: 0>()
# ----> 1 autoencoder.save("autoencoder.h5")
#
# NameError: name 'autoencoder' is not defined

# %%
autoencoder.save("autoencoder.keras")

# %%
import gradio as gr

def denoise_ct(image):
    import cv2
    import numpy as np

    # Resize to 128x128 and normalize
    img = cv2.resize(image, (128,128))
    img = img.astype('float32') / 255.0
    img = np.expand_dims(img, axis=(0,-1))

    # Predict
    denoised = autoencoder.predict(img)[0,:,:,0]
    denoised = (denoised * 255).astype('uint8')
    return denoised

interface = gr.Interface(
    fn=denoise_ct,
    inputs=gr.Image(type="numpy", image_mode='L'),  # removed 'shape'
    outputs=gr.Image(type="numpy", image_mode='L'), # removed 'shape'
    title="CT Scan Denoiser",
    description="Upload a CT scan image, and the autoencoder will denoise it."
)

interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://c5c99a72095a562bc6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c5c99a72095a562bc6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# %%writefile app.py
import gradio as gr

def denoise_ct(image):
    import cv2
    import numpy as np

    # Resize to 128x128 and normalize
    img = cv2.resize(image, (128,128))
    img = img.astype('float32') / 255.0
    img = np.expand_dims(img, axis=(0,-1))

    # Predict
    denoised = autoencoder.predict(img)[0,:,:,0]
    denoised = (denoised * 255).astype('uint8')
    return denoised

interface = gr.Interface(
    fn=denoise_ct,
    inputs=gr.Image(type="numpy", image_mode='L'),  # removed 'shape'
    outputs=gr.Image(type="numpy", image_mode='L'), # removed 'shape'
    title="CT Scan Denoiser",
    description="Upload a CT scan image, and the autoencoder will denoise it."
)

interface.launch()
# Out:
# Writing app.py

# %%
# %%writefile requirements.txt
# gradio
# opencv-python
# numpy
# tensorflow
# Out:
# Writing requirements.txt

# %%
# !pip install gradio huggingface_hub
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.43.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.12.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.12.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.16.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio) (15.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.19.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.8)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %% [markdown]
# PSNR

# %%
# For example, pick the first image
clean_img = X_test[0]         # Ground truth clean image
noisy_img = X_test_noisy[0]   # Noisy input

# %%
denoised_img = autoencoder.predict(np.expand_dims(noisy_img, axis=0))[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step

# %%
import math
import numpy as np

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 100
    PIXEL_MAX = 1.0  # images normalized between 0 and 1
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

psnr_score = psnr(denoised_img, clean_img)
print("PSNR:", psnr_score)
# Out:
# PSNR: 25.43761706638302

# %% [markdown]
# SSIM

# %%
from skimage.metrics import structural_similarity as ssim

# Ensure images are squeezed (H x W) and normalized between 0 and 1
clean_img_squeezed = clean_img.squeeze()
denoised_img_squeezed = denoised_img.squeeze()

ssim_score = ssim(clean_img_squeezed, denoised_img_squeezed, data_range=1.0)
print("SSIM:", ssim_score)
# Out:
# SSIM: 0.77727628572654

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `Map` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Map`

# %%
# !git config --global credential.helper store

# %%
# !gradio deploy
# Out:
# Creating new Spaces Repo in '/content'. Collecting metadata, press Enter to
# accept default value.
# Enter Spaces app title [content]: OptimaScan
# Enter Gradio app file [app.py]: app.py
# Enter Spaces hardware (cpu-basic, cpu-upgrade, cpu-xl, zero-a10g, t4-small, t4-medium, l4x1, l4x4, l40sx1, l40sx4, l40sx8, a10g-small, a10g-large, a10g-largex2, a10g-largex4, a100-large, h100, h100x8) [cpu-basic]: cpu-basic
# Any Spaces secrets (y/n) [n]: n
# Create Github Action to automatically update Space on 'git push'? [n]: n
# It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`hf upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#
#   /content/sample_data/mnist_test.csv   :  91% 16.6M/18.3M [00:00<?, ?B/s]
#
# Processing Files (0 / 1)                :   8% 16.6M/198M [00:00<00:06, 29.9MB/s, 91.7MB/s  ]
#
#
#   ...t/sample_data/mnist_train_small.csv:  69% 25.1M/36.5M [00:00<?, ?B/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:00<00:00, 8.63MB/s]
#
#
# Processing Files (1 / 2)                :  22% 43.4M/198M [00:00<00:02, 66.2MB/s,  114MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:00<00:00, 4.21MB/s]
#
#
# Processing Files (1 / 2)                :  26% 51.8M/198M [00:00<00:02, 58.3MB/s, 89.2MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:00<00:00, 2.78MB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv:  92% 33.5M/36.5M [00:00<00:00, 21.0MB/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:00<00:00, 2.08MB/s]
#
#
# Processing Files (2 / 2)                :  28% 54.8M/198M [00:01<00:04, 33.6MB/s, 55.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:00<00:00, 1.66MB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:00<00:00, 14.2MB/s]
#
#
#
#   /content/trainA.zip                   :   1% 524k/99.2M [00:00<?, ?B/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:01<00:00, 1.38MB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:01<00:00, 11.4MB/s]
#
#
#
# Processing Files (2 / 3)                :  28% 55.3M/198M [00:01<00:07, 20.4MB/s, 40.1MB/s  ]
# New Data Upload                         :   0% 524k/111M [00:01<06:09, 300kB/s,  379kB/s  ]
#
#
#
#
#   /content/autoencoder.h5               :   1% 11.2k/940k [00:00<?, ?B/s]
#
#
#
#
#
#   /content/autoencoder.keras            :   1% 11.2k/943k [00:00<?, ?B/s]
#
#
#
#
#
#
#   /content/testA.zip                    :   1% 505k/42.4M [00:00<?, ?B/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:01<00:00, 1.18MB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:01<00:00, 9.50MB/s]
#
#
#
#   /content/trainA.zip                   :  12% 11.5M/99.2M [00:00<00:01, 54.8MB/s]
#
#
#
#
#   /content/autoencoder.h5               :   1% 11.2k/940k [00:00<?, ?B/s]
#
#
#
#
#
#   /content/autoencoder.keras            :   1% 11.2k/943k [00:00<?, ?B/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  34% 66.9M/198M [00:01<00:04, 28.8MB/s, 42.3MB/s  ]
# New Data Upload                         :   8% 12.1M/144M [00:01<00:15, 8.36MB/s, 7.63MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:01<00:00, 1.03MB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:01<00:00, 8.14MB/s]
#
#
#
#   /content/trainA.zip                   :  30% 29.9M/99.2M [00:00<00:00, 73.4MB/s]
#
#
#
#
#   /content/autoencoder.h5               :   4% 33.6k/940k [00:00<00:08, 112kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :   4% 33.7k/943k [00:00<00:08, 112kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  44% 86.3M/198M [00:02<00:02, 45.5MB/s, 48.4MB/s  ]
# New Data Upload                         :  22% 31.5M/144M [00:02<00:04, 23.2MB/s, 17.7MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:01<00:00, 916kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:01<00:00, 7.13MB/s]
#
#
#
#   /content/trainA.zip                   :  50% 49.3M/99.2M [00:00<00:00, 81.3MB/s]
#
#
#
#
#   /content/autoencoder.h5               :   5% 44.8k/940k [00:00<00:10, 84.1kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :   5% 44.9k/943k [00:00<00:10, 84.3kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  54% 106M/198M [00:02<00:01, 59.5MB/s, 53.6MB/s  ]
# New Data Upload                         :  36% 51.4M/144M [00:02<00:02, 38.0MB/s, 25.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:01<00:00, 824kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:01<00:00, 6.34MB/s]
#
#
#
#   /content/trainA.zip                   :  69% 68.7M/99.2M [00:00<00:00, 85.2MB/s]
#
#
#
#
#   /content/autoencoder.h5               :   7% 67.2k/940k [00:00<00:09, 93.3kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :   7% 67.4k/943k [00:00<00:09, 93.6kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  64% 127M/198M [00:02<00:01, 71.0MB/s, 58.1MB/s  ]
# New Data Upload                         :  50% 71.8M/144M [00:02<00:01, 51.8MB/s, 32.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:02<00:00, 749kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:01<00:00, 5.70MB/s]
#
#
#
#   /content/trainA.zip                   :  71% 70.8M/99.2M [00:00<00:00, 70.3MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  10% 89.6k/940k [00:00<00:08, 98.1kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  10% 89.8k/943k [00:00<00:08, 98.4kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  65% 130M/198M [00:02<00:01, 55.7MB/s, 54.5MB/s  ]
# New Data Upload                         :  52% 75.0M/144M [00:02<00:01, 43.4MB/s, 31.5MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:02<00:00, 686kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:02<00:00, 5.18MB/s]
#
#
#
#   /content/trainA.zip                   :  72% 71.8M/99.2M [00:01<00:00, 59.4MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  12% 112k/940k [00:00<00:08, 101kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  12% 112k/943k [00:00<00:08, 101kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  67% 132M/198M [00:02<00:01, 42.8MB/s, 51.1MB/s  ]
# New Data Upload                         :  54% 77.1M/144M [00:02<00:01, 35.1MB/s, 29.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:02<00:00, 633kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:02<00:00, 4.75MB/s]
#
#
#
#   /content/trainA.zip                   :  73% 72.9M/99.2M [00:01<00:00, 51.7MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  14% 134k/940k [00:01<00:07, 103kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  14% 135k/943k [00:01<00:07, 103kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  68% 134M/198M [00:03<00:01, 33.5MB/s, 48.2MB/s  ]
# New Data Upload                         :  55% 79.2M/144M [00:03<00:02, 28.6MB/s, 28.5MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:02<00:00, 588kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:02<00:00, 4.39MB/s]
#
#
#
#   /content/trainA.zip                   :  75% 74.5M/99.2M [00:01<00:00, 46.2MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  18% 168k/940k [00:01<00:06, 112kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  18% 168k/943k [00:01<00:06, 112kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  69% 137M/198M [00:03<00:02, 28.3MB/s, 46.0MB/s  ]
# New Data Upload                         :  57% 82.4M/144M [00:03<00:02, 25.1MB/s, 27.6MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:02<00:00, 548kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:02<00:00, 4.07MB/s]
#
#
#
#   /content/trainA.zip                   :  77% 76.0M/99.2M [00:01<00:00, 41.9MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  20% 190k/940k [00:01<00:06, 112kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  20% 191k/943k [00:01<00:06, 112kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  70% 140M/198M [00:03<00:02, 23.8MB/s, 43.9MB/s  ]
# New Data Upload                         :  59% 85.0M/144M [00:03<00:02, 21.7MB/s, 26.7MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:03<00:00, 514kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:02<00:00, 3.80MB/s]
#
#
#
#   /content/trainA.zip                   :  78% 77.6M/99.2M [00:01<00:00, 38.5MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  23% 213k/940k [00:01<00:06, 112kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  23% 213k/943k [00:01<00:06, 112kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  72% 142M/198M [00:03<00:02, 20.7MB/s, 42.1MB/s  ]
# New Data Upload                         :  61% 87.6M/144M [00:03<00:02, 19.2MB/s, 25.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:03<00:00, 484kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:03<00:00, 3.56MB/s]
#
#
#
#   /content/trainA.zip                   :  79% 78.7M/99.2M [00:02<00:00, 35.5MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  26% 246k/940k [00:01<00:05, 118kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  26% 247k/943k [00:01<00:05, 118kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  73% 145M/198M [00:03<00:02, 18.4MB/s, 40.5MB/s  ]
# New Data Upload                         :  63% 90.3M/144M [00:03<00:03, 17.5MB/s, 25.2MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:03<00:00, 457kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:03<00:00, 3.35MB/s]
#
#
#
#   /content/trainA.zip                   :  81% 80.2M/99.2M [00:02<00:00, 33.2MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  29% 269k/940k [00:02<00:05, 117kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  29% 269k/943k [00:02<00:05, 117kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  74% 148M/198M [00:04<00:02, 16.9MB/s, 39.1MB/s  ]
# New Data Upload                         :  65% 92.9M/144M [00:04<00:03, 16.2MB/s, 24.6MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:03<00:00, 433kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:03<00:00, 3.17MB/s]
#
#
#
#   /content/trainA.zip                   :  82% 81.3M/99.2M [00:02<00:00, 31.1MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  32% 302k/940k [00:02<00:05, 121kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  32% 303k/943k [00:02<00:05, 122kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  76% 150M/198M [00:04<00:03, 15.8MB/s, 37.8MB/s  ]
# New Data Upload                         :  67% 95.5M/144M [00:04<00:03, 15.3MB/s, 24.0MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:03<00:00, 411kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:03<00:00, 3.00MB/s]
#
#
#
#   /content/trainA.zip                   :  84% 82.9M/99.2M [00:02<00:00, 29.4MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  36% 336k/940k [00:02<00:04, 125kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  36% 337k/943k [00:02<00:04, 125kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  77% 153M/198M [00:04<00:02, 15.8MB/s, 36.7MB/s  ]
# New Data Upload                         :  69% 98.7M/144M [00:04<00:02, 15.5MB/s, 23.6MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:04<00:00, 391kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:04<00:00, 2.85MB/s]
#
#
#
#   /content/trainA.zip                   :  85% 84.5M/99.2M [00:02<00:00, 28.0MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  38% 358k/940k [00:02<00:04, 124kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  38% 359k/943k [00:02<00:04, 124kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  79% 156M/198M [00:04<00:02, 15.0MB/s, 35.6MB/s  ]
# New Data Upload                         :  71% 101M/144M [00:04<00:02, 14.8MB/s, 23.1MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:04<00:00, 373kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:04<00:00, 2.72MB/s]
#
#
#
#   /content/trainA.zip                   :  87% 86.0M/99.2M [00:03<00:00, 26.7MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  42% 392k/940k [00:02<00:04, 127kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  42% 393k/943k [00:02<00:04, 127kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  80% 159M/198M [00:04<00:02, 15.2MB/s, 34.8MB/s  ]
# New Data Upload                         :  73% 104M/144M [00:04<00:02, 15.1MB/s, 22.8MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:04<00:00, 357kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:04<00:00, 2.59MB/s]
#
#
#
#   /content/trainA.zip                   :  88% 87.1M/99.2M [00:03<00:00, 25.5MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  45% 425k/940k [00:03<00:03, 129kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  45% 427k/943k [00:03<00:03, 130kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  82% 162M/198M [00:05<00:02, 14.6MB/s, 33.9MB/s  ]
# New Data Upload                         :  75% 107M/144M [00:05<00:02, 14.5MB/s, 22.4MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:04<00:00, 342kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:04<00:00, 2.48MB/s]
#
#
#
#   /content/trainA.zip                   :  89% 88.7M/99.2M [00:03<00:00, 24.5MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  49% 459k/940k [00:03<00:03, 132kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  49% 460k/943k [00:03<00:03, 132kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  83% 165M/198M [00:05<00:02, 15.0MB/s, 33.1MB/s  ]
# New Data Upload                         :  77% 110M/144M [00:05<00:02, 14.9MB/s, 22.1MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:04<00:00, 329kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:04<00:00, 2.38MB/s]
#
#
#
#   /content/trainA.zip                   :  91% 90.8M/99.2M [00:03<00:00, 23.7MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  52% 493k/940k [00:03<00:03, 134kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  52% 494k/943k [00:03<00:03, 134kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  85% 169M/198M [00:05<00:01, 16.0MB/s, 32.6MB/s  ]
# New Data Upload                         :  79% 114M/144M [00:05<00:01, 15.9MB/s, 22.0MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:05<00:00, 316kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:04<00:00, 2.28MB/s]
#
#
#
#   /content/trainA.zip                   :  93% 92.3M/99.2M [00:03<00:00, 23.0MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  56% 526k/940k [00:03<00:03, 136kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  56% 528k/943k [00:03<00:03, 136kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  87% 172M/198M [00:05<00:01, 15.9MB/s, 31.9MB/s  ]
# New Data Upload                         :  82% 117M/144M [00:05<00:01, 15.9MB/s, 21.8MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:05<00:00, 304kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:05<00:00, 2.19MB/s]
#
#
#
#   /content/trainA.zip                   :  95% 93.9M/99.2M [00:04<00:00, 22.2MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  60% 560k/940k [00:03<00:02, 137kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  60% 561k/943k [00:03<00:02, 138kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  88% 175M/198M [00:05<00:01, 15.9MB/s, 31.4MB/s  ]
# New Data Upload                         :  84% 120M/144M [00:05<00:01, 15.9MB/s, 21.5MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:05<00:00, 293kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:05<00:00, 2.11MB/s]
#
#
#
#   /content/trainA.zip                   :  96% 95.5M/99.2M [00:04<00:00, 21.6MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  64% 605k/940k [00:04<00:02, 141kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  64% 606k/943k [00:04<00:02, 142kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  90% 179M/198M [00:06<00:01, 16.7MB/s, 30.9MB/s  ]
# New Data Upload                         :  86% 124M/144M [00:06<00:01, 16.6MB/s, 21.4MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:05<00:00, 283kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:05<00:00, 2.04MB/s]
#
#
#
#   /content/trainA.zip                   :  98% 97.6M/99.2M [00:04<00:00, 21.1MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  68% 638k/940k [00:04<00:02, 142kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  68% 640k/943k [00:04<00:02, 143kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  92% 182M/198M [00:06<00:00, 17.2MB/s, 30.5MB/s  ]
# New Data Upload                         :  89% 128M/144M [00:06<00:00, 17.2MB/s, 21.3MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:05<00:00, 274kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:05<00:00, 1.97MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:04<00:00, 20.6MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  71% 672k/940k [00:04<00:01, 144kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  71% 674k/943k [00:04<00:01, 144kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  94% 186M/198M [00:06<00:00, 16.8MB/s, 30.0MB/s  ]
# New Data Upload                         :  91% 131M/144M [00:06<00:00, 16.8MB/s, 21.2MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:06<00:00, 265kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:05<00:00, 1.90MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:04<00:00, 19.7MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  76% 717k/940k [00:04<00:01, 147kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  76% 718k/943k [00:04<00:01, 147kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  95% 188M/198M [00:06<00:00, 14.9MB/s, 29.4MB/s  ]
# New Data Upload                         :  93% 133M/144M [00:06<00:00, 14.9MB/s, 20.8MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:06<00:00, 257kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:06<00:00, 1.84MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:05<00:00, 19.0MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  80% 750k/940k [00:04<00:01, 148kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  80% 752k/943k [00:04<00:01, 148kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  95% 189M/198M [00:06<00:00, 12.8MB/s, 28.8MB/s  ]
# New Data Upload                         :  94% 134M/144M [00:06<00:00, 12.8MB/s, 20.4MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:06<00:00, 249kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:06<00:00, 1.78MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:05<00:00, 18.3MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  85% 795k/940k [00:05<00:00, 151kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  85% 797k/943k [00:05<00:00, 151kB/s]
#
#
#
#
#
#
# Processing Files (2 / 6)                :  97% 191M/198M [00:07<00:00, 12.1MB/s, 28.2MB/s  ]
# New Data Upload                         :  95% 137M/144M [00:07<00:00, 12.1MB/s, 20.1MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:06<00:00, 241kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:06<00:00, 1.73MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:05<00:00, 17.6MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  89% 840k/940k [00:05<00:00, 153kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  89% 842k/943k [00:05<00:00, 154kB/s]
#
#
#
#
#
#
# Processing Files (3 / 6)                :  98% 194M/198M [00:07<00:00, 11.7MB/s, 27.7MB/s  ]
# New Data Upload                         :  97% 139M/144M [00:07<00:00, 11.7MB/s, 19.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:06<00:00, 235kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:06<00:00, 1.68MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:05<00:00, 17.0MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  93% 873k/940k [00:05<00:00, 154kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  93% 876k/943k [00:05<00:00, 154kB/s]
#
#
#
#
#
#
# Processing Files (3 / 6)                :  98% 195M/198M [00:07<00:00, 10.6MB/s, 27.2MB/s  ]
# New Data Upload                         :  98% 140M/144M [00:07<00:00, 10.6MB/s, 19.5MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:07<00:00, 228kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:06<00:00, 1.63MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:05<00:00, 16.5MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  98% 918k/940k [00:05<00:00, 156kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  98% 921k/943k [00:05<00:00, 157kB/s]
#
#
#
#
#
#
# Processing Files (3 / 6)                :  99% 197M/198M [00:07<00:00, 10.6MB/s, 26.7MB/s  ]
# New Data Upload                         :  99% 142M/144M [00:07<00:00, 10.6MB/s, 19.3MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:07<00:00, 222kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:07<00:00, 1.58MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:06<00:00, 15.9MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  99% 929k/940k [00:05<00:00, 153kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  99% 932k/943k [00:05<00:00, 153kB/s]
#
#
#
#
#
#
# Processing Files (3 / 6)                : 100% 198M/198M [00:07<00:00, 8.20MB/s, 26.1MB/s  ]
# New Data Upload                         : 100% 143M/144M [00:07<00:00, 8.20MB/s, 18.9MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:07<00:00, 216kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:07<00:00, 1.54MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:06<00:00, 15.4MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  99% 929k/940k [00:06<00:00, 148kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  99% 932k/943k [00:06<00:00, 148kB/s]
#
#
#
#
#
#
#   /content/testA.zip                    :  99% 41.9M/42.4M [00:06<00:00, 6.67MB/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:07<00:00, 210kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:07<00:00, 1.50MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:06<00:00, 15.0MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  99% 929k/940k [00:06<00:00, 143kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  99% 932k/943k [00:06<00:00, 144kB/s]
#
#
#
#
#
#
#   /content/testA.zip                    :  99% 41.9M/42.4M [00:06<00:00, 6.47MB/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:07<00:00, 205kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:07<00:00, 1.46MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:06<00:00, 14.5MB/s]
#
#
#
#
#   /content/autoencoder.h5               :  99% 929k/940k [00:06<00:00, 139kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            :  99% 932k/943k [00:06<00:00, 139kB/s]
#
#
#
#
#
#
#   /content/testA.zip                    :  99% 41.9M/42.4M [00:06<00:00, 6.27MB/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:08<00:00, 200kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:07<00:00, 1.43MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:06<00:00, 14.1MB/s]
#
#
#
#
#   /content/autoencoder.h5               : 100% 940k/940k [00:06<00:00, 137kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            : 100% 943k/943k [00:06<00:00, 137kB/s]
#
#
#
#
#
#
# Processing Files (6 / 6)                : 100% 198M/198M [00:08<00:00, 3.43MB/s, 23.7MB/s  ]
# New Data Upload                         : 100% 144M/144M [00:08<00:00, 3.43MB/s, 17.1MB/s  ]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:08<00:00, 197kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:08<00:00, 1.40MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:07<00:00, 13.8MB/s]
#
#
#
#
#   /content/autoencoder.h5               : 100% 940k/940k [00:06<00:00, 134kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            : 100% 943k/943k [00:06<00:00, 134kB/s]
#
#
#
#
#
#
#   /content/testA.zip                    : 100% 42.4M/42.4M [00:06<00:00, 6.02MB/s]
#
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:08<00:00, 195kB/s]
#
#
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:08<00:00, 1.39MB/s]
#
#
#
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:07<00:00, 13.7MB/s]
#
#
#
#
#   /content/autoencoder.h5               : 100% 940k/940k [00:06<00:00, 133kB/s]
#
#
#
#
#
#   /content/autoencoder.keras            : 100% 943k/943k [00:06<00:00, 133kB/s]
#
#
#
#
#
#
# Processing Files (6 / 6)                : 100% 198M/198M [00:08<00:00, 22.2MB/s, 23.1MB/s  ]
# New Data Upload                         : 100% 144M/144M [00:08<00:00, 16.0MB/s, 16.7MB/s  ]
#   /content/sample_data/mnist_test.csv   : 100% 18.3M/18.3M [00:08<00:00, 195kB/s]
#   ...t/sample_data/mnist_train_small.csv: 100% 36.5M/36.5M [00:08<00:00, 1.39MB/s]
#   /content/trainA.zip                   : 100% 99.2M/99.2M [00:07<00:00, 13.7MB/s]
#   /content/autoencoder.h5               : 100% 940k/940k [00:07<00:00, 133kB/s]
#   /content/autoencoder.keras            : 100% 943k/943k [00:07<00:00, 133kB/s]
#   /content/testA.zip                    : 100% 42.4M/42.4M [00:07<00:00, 5.98MB/s]
# Space available at https://huggingface.co/spaces/Piyusha21/OptimaScan
